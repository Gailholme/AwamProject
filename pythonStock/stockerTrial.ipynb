# %%
from stocker import Stocker
# Out:
# INFO:matplotlib.font_manager:font search path ['c:\\users\\lutear\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf', 'c:\\users\\lutear\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\afm', 'c:\\users\\lutear\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\pdfcorefonts']
# INFO:matplotlib.font_manager:generated new fontManager

# %%
microsoft = Stocker('MSFT')
mcdonald = Stocker('MCD')
# Out:
# D:\Gail's work\stocker.py:70: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   self.starting_price = float(self.stock.ix[0, 'Adj. Open'])
# D:\Gail's work\stocker.py:73: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   self.most_recent_price = float(self.stock.ix[len(self.stock) - 1, 'y'])
# MSFT Stocker Initialized. Data covers 1986-03-13 to 2018-03-27.
# MCD Stocker Initialized. Data covers 1970-01-02 to 2018-03-27.

# %%
# Stock is an attribute of the microsoft object
stock_history = microsoft.stock
stock_history.head()
# Out:
#         Date   Open   High   Low  Close     Volume  Ex-Dividend  Split Ratio  \
# 0 1986-03-13  25.50  29.25  25.5  28.00  3582600.0          0.0          1.0
# 1 1986-03-14  28.00  29.50  28.0  29.00  1070000.0          0.0          1.0
# 2 1986-03-17  29.00  29.75  29.0  29.50   462400.0          0.0          1.0
# 3 1986-03-18  29.50  29.75  28.5  28.75   235300.0          0.0          1.0
# 4 1986-03-19  28.75  29.00  28.0  28.25   166300.0          0.0          1.0
#
#    Adj. Open  Adj. High  Adj. Low  Adj. Close   Adj. Volume         ds  \
# 0   0.058941   0.067609  0.058941    0.064720  1.031789e+09 1986-03-13
# 1   0.064720   0.068187  0.064720    0.067031  3.081600e+08 1986-03-14
# 2   0.067031   0.068765  0.067031    0.068187  1.331712e+08 1986-03-17
# 3   0.068187   0.068765  0.065876    0.066454  6.776640e+07 1986-03-18
# 4   0.066454   0.067031  0.064720    0.065298  4.789440e+07 1986-03-19
#
#           y  Daily Change
# 0  0.064720      0.005779
# ...

# %%
# A method (function) requires parentheses
microsoft.plot_stock()
# Out:
# D:\Gail's work\stocker.py:178: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   trim_df = df[(df['Date'] >= start_date.date()) &
# D:\Gail's work\stocker.py:179: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (df['Date'] <= end_date.date())]
# D:\Gail's work\stocker.py:249: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# ...

# %%
# A method (function) requires parentheses
mcdonald.plot_stock()
# Out:
# Maximum Adj. Close = 178.36 on 2018-01-26.
# Minimum Adj. Close = 0.13 on 1970-05-26.
# Current Adj. Close = 157.48 on 2018-03-27.
# D:\Gail's work\stocker.py:178: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   trim_df = df[(df['Date'] >= start_date.date()) &
# D:\Gail's work\stocker.py:179: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (df['Date'] <= end_date.date())]
# D:\Gail's work\stocker.py:249: DeprecationWarning:
# .ix is deprecated. Please use
# ...

# %%
mcdonald.plot_stock(start_date = '2000-01-03',  end_date = '2018-01-16',  stats = ['Daily Change', 'Adj. Volume'],  plot_type='pct')
# Out:
# D:\Gail's work\stocker.py:178: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   trim_df = df[(df['Date'] >= start_date.date()) &
# D:\Gail's work\stocker.py:179: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (df['Date'] <= end_date.date())]
# D:\Gail's work\stocker.py:249: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# ...

# %%
mcdonald.buy_and_hold(start_date='1986-03-13', 
                       end_date='2018-01-16', nshares=100)
# Out:
# D:\Gail's work\stocker.py:178: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   trim_df = df[(df['Date'] >= start_date.date()) &
# D:\Gail's work\stocker.py:179: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (df['Date'] <= end_date.date())]
# MCD Total buy and hold profit from 1986-03-13 to 2018-01-16 for 100 shares = $17079.32

# %%
model, model_data = microsoft.create_prophet_model()
# model and model_data are from previous method call
model.plot_components(model_data)
plt.show()
# Out:
# D:\Gail's work\stocker.py:444: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   stock_history = self.stock[self.stock['Date'] > (self.max_date - pd.DateOffset(years = self.training_years)).date()]
# c:\users\lutear\appdata\local\programs\python\python36\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
